# %%
import numpy as np
import matplotlib.pyplot as plt
import netCDF4 as nc

def plot_histogram(filtered_data, value_range):
    plt.figure(figsize=(10, 6))
    bins = np.linspace(value_range[0], value_range[1], 11)
    hist, bins, patches = plt.hist(filtered_data, bins=bins, edgecolor='black', color='blue')
    
    plt.xticks(bins)
    
    y_max = max(hist)
    a = 10 ** (len(str(int(y_max))) - 1)
    arr = np.arange(0, y_max + a, a)
    
    plt.yticks(arr)
    
    plt.xlabel('Chlorophyll-a Values')
    plt.ylabel('Frequency')
    plt.title('Histogram of Chlorophyll-a Data')
    
    plt.show()

def plot_cdf(filtered_data, value_range):
    plt.figure(figsize=(10, 6))
    sorted_data = np.sort(filtered_data)
    
    cdf = np.arange(1, len(sorted_data) + 1) / len(sorted_data)
    
    plt.plot(sorted_data, cdf, marker='.', linestyle='none')
    
    plt.xlabel('Chlorophyll-a Values')
    plt.ylabel('CDF')
    plt.title('CDF of Chlorophyll-a Data')
    
    plt.grid(True)
    plt.show()

nc_file = nc.Dataset('AQUA_MODIS.20020101_20021231.L3m.YR.CHL.chlor_a.4km.nc', 'r')
sst_data = np.array(nc_file.variables['chlor_a'][:])
fill_value = -32767.0
sst_data = np.where(sst_data == fill_value, np.nan, sst_data)

test_sst_data = sst_data[~np.isnan(sst_data)]

regional_pixels_global = test_sst_data.shape[0]
latitudes = nc_file.variables['lat'][:]
longitudes = nc_file.variables['lon'][:]

nc_file.close()

print("Total Global Pixels",regional_pixels_global)

latitude_bands = {
    "30N-30S": (latitudes >= -30) & (latitudes <= 30),
    "60N-60S": (latitudes >= -60) & (latitudes <= 60),
    "90N-90S": np.full_like(latitudes, True, dtype=bool),
    #"(30-60)N-(30-60)S": ((latitudes >= -60) & (latitudes <= -30)) | ((latitudes >= 30) & (latitudes <= 60)),
    #"(60-90)N-(60-90)S": ((latitudes >= -90) & (latitudes <= -60)) | ((latitudes >= 60) & (latitudes <= 90))
}

value_ranges = [
    (0, 1), (0, 0.5), (0, 0.25), (0, 0.1),
    (0.01, 1), (0.01, 0.5), (0.01, 0.25), (0.01, 0.1)
]

def calculate_metrics(filtered_data):
    mean_value = np.nanmean(filtered_data)
    std_dev = np.nanstd(filtered_data)
    percentiles = np.nanpercentile(filtered_data, [50, 80, 90])
    return mean_value, std_dev, percentiles

for band_name, band_filter in latitude_bands.items():
    band_lat_indices = np.where(band_filter)[0]
    filtered_data = sst_data[band_lat_indices, :]
    filtered_data = filtered_data[~np.isnan(filtered_data)]

    for value_range in value_ranges:
        range_filter = (filtered_data >= value_range[0]) & (filtered_data <= value_range[1])
        filtered_values = filtered_data[range_filter]
        regional_pixels_local=filtered_data.shape[0]
        valid_pixels = filtered_values.shape[0]
        Fraction_Valid_local = valid_pixels / regional_pixels_local
        Fraction_Valid_global = valid_pixels / regional_pixels_global
        
        if valid_pixels > 0:
            mean_value, std_dev, percentiles = calculate_metrics(filtered_values)
            print(f"\nLatitude Band: {band_name}")
            print(f"Value Range: {value_range}")
            print(f"Valid Pixels: {valid_pixels}")
            print(f"Fraction Valid wrt local region: {Fraction_Valid_local}")
            print(f"Fraction Valid wrt global region: {Fraction_Valid_global}")
            print(f"Mean: {mean_value}")
            print(f"Standard Deviation: {std_dev}")
            print(f"50th Percentile: {percentiles[0]}")
            print(f"80th Percentile: {percentiles[1]}")
            print(f"90th Percentile: {percentiles[2]}")
            plot_histogram(filtered_values, value_range)
            plot_cdf(filtered_values, value_range)
        else:
            print(f"\nLatitude Band: {band_name}")
            print(f"Value Range: {value_range}")
            print("No data in this range.")
# Out:
# Total Global Pixels 21290181
#
# Latitude Band: 30N-30S
# Value Range: (0, 1)
# Valid Pixels: 8967272
# Fraction Valid wrt local region: 0.9688086985513579
# Fraction Valid wrt global region: 0.4211928494172971
# Mean: 0.13407954573631287
# Standard Deviation: 0.13152682781219482
# 50th Percentile: 0.09573230892419815
# 80th Percentile: 0.1794948130846024
# 90th Percentile: 0.2692581951618197
# Latitude Band: 30N-30S
# Value Range: (0, 0.5)
# Valid Pixels: 8696795
# Fraction Valid wrt local region: 0.9395868270214125
# Fraction Valid wrt global region: 0.4084885422063814
# Mean: 0.11748214066028595
# Standard Deviation: 0.0901465192437172
# 50th Percentile: 0.09250044077634811
# 80th Percentile: 0.16875775754451752
# 90th Percentile: 0.22960747480392468
# Latitude Band: 30N-30S
# Value Range: (0, 0.25)
# Valid Pixels: 7966373
# Fraction Valid wrt local region: 0.860673285956384
# Fraction Valid wrt global region: 0.37418061405865927
# Mean: 0.09636162221431732
# Standard Deviation: 0.05577041208744049
# 50th Percentile: 0.08399660885334015
# 80th Percentile: 0.1473961412906647
# 90th Percentile: 0.17928016781806944
# Latitude Band: 30N-30S
# Value Range: (0, 0.1)
# Valid Pixels: 4654611
# Fraction Valid wrt local region: 0.5028761952545695
# Fraction Valid wrt global region: 0.21862712205217982
# Mean: 0.0562460757791996
# Standard Deviation: 0.02147880755364895
# 50th Percentile: 0.05295558273792267
# 80th Percentile: 0.0780409500002861
# 90th Percentile: 0.08883072435855865
# Latitude Band: 30N-30S
# Value Range: (0.01, 1)
# Valid Pixels: 8967271
# Fraction Valid wrt local region: 0.9688085905130717
# Fraction Valid wrt global region: 0.4211928024472878
# Mean: 0.13407953083515167
# Standard Deviation: 0.13152679800987244
# 50th Percentile: 0.09573232382535934
# 80th Percentile: 0.17949482798576355
# 90th Percentile: 0.2692582607269287
# Latitude Band: 30N-30S
# Value Range: (0.01, 0.5)
# Valid Pixels: 8696794
# Fraction Valid wrt local region: 0.9395867189831264
# Fraction Valid wrt global region: 0.4084884952363721
# Mean: 0.11748220026493073
# Standard Deviation: 0.09014654159545898
# 50th Percentile: 0.09250045567750931
# 80th Percentile: 0.168757763504982
# 90th Percentile: 0.22960749417543413
# Latitude Band: 30N-30S
# Value Range: (0.01, 0.25)
# Valid Pixels: 7966372
# Fraction Valid wrt local region: 0.8606731779180979
# Fraction Valid wrt global region: 0.37418056708864994
# Mean: 0.09636165201663971
# Standard Deviation: 0.055770404636859894
# 50th Percentile: 0.08399662002921104
# 80th Percentile: 0.14739614427089692
# 90th Percentile: 0.17928017228841783
# Latitude Band: 30N-30S
# Value Range: (0.01, 0.1)
# Valid Pixels: 4654610
# Fraction Valid wrt local region: 0.5028760872162834
# Fraction Valid wrt global region: 0.2186270750821705
# Mean: 0.056246090680360794
# Standard Deviation: 0.021478796377778053
# 50th Percentile: 0.05295558273792267
# 80th Percentile: 0.07804095447063447
# 90th Percentile: 0.08883072882890702
# Latitude Band: 60N-60S
# Value Range: (0, 1)
# Valid Pixels: 17355461
# Fraction Valid wrt local region: 0.9510375788229202
# Fraction Valid wrt global region: 0.8151861649273907
# Mean: 0.18976163864135742
# Standard Deviation: 0.16657204926013947
# 50th Percentile: 0.1409912109375
# 80th Percentile: 0.27105334401130676
# 90th Percentile: 0.4049546718597412
# Latitude Band: 60N-60S
# Value Range: (0, 0.5)
# Valid Pixels: 16271035
# Fraction Valid wrt local region: 0.8916136385742213
# Fraction Valid wrt global region: 0.7642506656002596
# Mean: 0.1571969985961914
# Standard Deviation: 0.1065053716301918
# 50th Percentile: 0.13294203579425812
# 80th Percentile: 0.23280826210975647
# 90th Percentile: 0.3173430263996124
# Latitude Band: 60N-60S
# Value Range: (0, 0.25)
# Valid Pixels: 13445143
# Fraction Valid wrt local region: 0.7367615441415203
# Fraction Valid wrt global region: 0.6315184920222143
# Mean: 0.1174992173910141
# Standard Deviation: 0.0603393092751503
# 50th Percentile: 0.11310873925685883
# 80th Percentile: 0.1758483201265335
# 90th Percentile: 0.2047896683216095
# Latitude Band: 60N-60S
# Value Range: (0, 0.1)
# Valid Pixels: 5836810
# Fraction Valid wrt local region: 0.3198431692738907
# Fraction Valid wrt global region: 0.2741550201005806
# Mean: 0.06022517383098602
# Standard Deviation: 0.022180302068591118
# 50th Percentile: 0.05821073055267334
# 80th Percentile: 0.08347382098436357
# 90th Percentile: 0.09175278395414353
# Latitude Band: 60N-60S
# Value Range: (0.01, 1)
# Valid Pixels: 17355448
# Fraction Valid wrt local region: 0.9510368664541433
# Fraction Valid wrt global region: 0.8151855543172696
# Mean: 0.18976187705993652
# Standard Deviation: 0.16657201945781708
# 50th Percentile: 0.14099129289388657
# 80th Percentile: 0.2710535347461702
# 90th Percentile: 0.4049546897411347
# Latitude Band: 60N-60S
# Value Range: (0.01, 0.5)
# Valid Pixels: 16271022
# Fraction Valid wrt local region: 0.8916129262054444
# Fraction Valid wrt global region: 0.7642500549901384
# Mean: 0.1571970134973526
# Standard Deviation: 0.10650528967380524
# 50th Percentile: 0.13294213265180588
# 80th Percentile: 0.2328082859516144
# 90th Percentile: 0.3173430532217026
# Latitude Band: 60N-60S
# Value Range: (0.01, 0.25)
# Valid Pixels: 13445130
# Fraction Valid wrt local region: 0.7367608317727434
# Fraction Valid wrt global region: 0.6315178814120932
# Mean: 0.11749940365552902
# Standard Deviation: 0.06033927574753761
# 50th Percentile: 0.11310883983969688
# 80th Percentile: 0.17584841847419744
# 90th Percentile: 0.20478969812393188
# Latitude Band: 60N-60S
# Value Range: (0.01, 0.1)
# Valid Pixels: 5836797
# Fraction Valid wrt local region: 0.31984245690511387
# Fraction Valid wrt global region: 0.2741544094904595
# Mean: 0.060225240886211395
# Standard Deviation: 0.022180207073688507
# 50th Percentile: 0.058210816234350204
# 80th Percentile: 0.08347387462854386
# 90th Percentile: 0.0917527973651886
# Latitude Band: 90N-90S
# Value Range: (0, 1)
# Valid Pixels: 19797901
# Fraction Valid wrt local region: 0.929907594491564
# Fraction Valid wrt global region: 0.929907594491564
# Mean: 0.21131481230258942
# Standard Deviation: 0.1874496191740036
# 50th Percentile: 0.15026403963565826
# 80th Percentile: 0.312269389629364
# 90th Percentile: 0.4803459048271179
# Latitude Band: 90N-90S
# Value Range: (0, 0.5)
# Valid Pixels: 17977682
# Fraction Valid wrt local region: 0.8444118910966516
# Fraction Valid wrt global region: 0.8444118910966516
# Mean: 0.16368892788887024
# Standard Deviation: 0.11018934845924377
# 50th Percentile: 0.13780661672353745
# 80th Percentile: 0.2436931371688843
# 90th Percentile: 0.3335564553737641
# Latitude Band: 90N-90S
# Value Range: (0, 0.25)
# Valid Pixels: 14551346
# Fraction Valid wrt local region: 0.6834768572423128
# Fraction Valid wrt global region: 0.6834768572423128
# Mean: 0.11963964253664017
# Standard Deviation: 0.06028330698609352
# 50th Percentile: 0.11636598780751228
# 80th Percentile: 0.1778269112110138
# 90th Percentile: 0.20632074028253555
# Latitude Band: 90N-90S
# Value Range: (0, 0.1)
# Valid Pixels: 6035176
# Fraction Valid wrt local region: 0.28347227296940314
# Fraction Valid wrt global region: 0.28347227296940314
# Mean: 0.06052862107753754
# Standard Deviation: 0.02245018072426319
# 50th Percentile: 0.058654697611927986
# 80th Percentile: 0.08421332389116287
# 90th Percentile: 0.09220549091696739
# Latitude Band: 90N-90S
# Value Range: (0.01, 1)
# Valid Pixels: 19795130
# Fraction Valid wrt local region: 0.9297774405957375
# Fraction Valid wrt global region: 0.9297774405957375
# Mean: 0.21134351193904877
# Standard Deviation: 0.18744713068008423
# 50th Percentile: 0.1502830758690834
# 80th Percentile: 0.3123019337654114
# 90th Percentile: 0.4803784072399142
# Latitude Band: 90N-90S
# Value Range: (0.01, 0.5)
# Valid Pixels: 17974911
# Fraction Valid wrt local region: 0.8442817372008251
# Fraction Valid wrt global region: 0.8442817372008251
# Mean: 0.16371291875839233
# Standard Deviation: 0.11018075793981552
# 50th Percentile: 0.1378258764743805
# 80th Percentile: 0.24371343851089478
# 90th Percentile: 0.33357709646224976
# Latitude Band: 90N-90S
# Value Range: (0.01, 0.25)
# Valid Pixels: 14548575
# Fraction Valid wrt local region: 0.6833467033464864
# Fraction Valid wrt global region: 0.6833467033464864
# Mean: 0.11966082453727722
# Standard Deviation: 0.06026912480592728
# 50th Percentile: 0.11638427525758743
# 80th Percentile: 0.17783652544021608
# 90th Percentile: 0.2063274085521698
# Latitude Band: 90N-90S
# Value Range: (0.01, 0.1)
# Valid Pixels: 6032405
# Fraction Valid wrt local region: 0.2833421190735767
# Fraction Valid wrt global region: 0.2833421190735767
# Mean: 0.060552969574928284
# Standard Deviation: 0.022426526993513107
# 50th Percentile: 0.058672551065683365
# 80th Percentile: 0.08422106653451919
# 90th Percentile: 0.09220880270004278

# %%
import numpy as np
import matplotlib.pyplot as plt
import netCDF4 as nc

def plot_histogram(filtered_data, value_range):
    plt.figure(figsize=(10, 6))
    bins = np.linspace(value_range[0], value_range[1], 11)
    hist, bins, patches = plt.hist(filtered_data, bins=bins, edgecolor='black', color='blue')
    
    plt.xticks(bins)
    
    y_max = max(hist)
    a = 10 ** (len(str(int(y_max))) - 1)
    arr = np.arange(0, y_max + a, a)
    
    plt.yticks(arr)
    
    plt.xlabel('Chlorophyll-a Values')
    plt.ylabel('Frequency')
    plt.title('Histogram of Chlorophyll-a Data')
    
    plt.show()

def plot_cdf(filtered_data, value_range):
    plt.figure(figsize=(10, 6))
    sorted_data = np.sort(filtered_data)
    
    cdf = np.arange(1, len(sorted_data) + 1) / len(sorted_data)
    
    plt.plot(sorted_data, cdf, marker='.', linestyle='none')
    
    plt.xlabel('Chlorophyll-a Values')
    plt.ylabel('CDF')
    plt.title('CDF of Chlorophyll-a Data')
    
    plt.grid(True)
    plt.show()

nc_file = nc.Dataset('AQUA_MODIS.20020101_20021231.L3m.YR.CHL.chlor_a.4km.nc', 'r')
sst_data = np.array(nc_file.variables['chlor_a'][:])
fill_value = -32767.0
sst_data = np.where(sst_data == fill_value, np.nan, sst_data)

test_sst_data = sst_data[~np.isnan(sst_data)]

regional_pixels_global = test_sst_data.shape[0]
latitudes = nc_file.variables['lat'][:]
longitudes = nc_file.variables['lon'][:]

nc_file.close()

print("Total Global Pixels",regional_pixels_global)

latitude_bands = {
    #"30N-30S": (latitudes >= -30) & (latitudes <= 30),
    #"60N-60S": (latitudes >= -60) & (latitudes <= 60),
    #"90N-90S": np.full_like(latitudes, True, dtype=bool),
    "(30-60)N-(30-60)S": ((latitudes >= -60) & (latitudes <= -30)) | ((latitudes >= 30) & (latitudes <= 60)),
    "(60-90)N-(60-90)S": ((latitudes >= -90) & (latitudes <= -60)) | ((latitudes >= 60) & (latitudes <= 90))
}

value_ranges = [
    (0, 1), (0, 2), (1, 2)
]

def calculate_metrics(filtered_data):
    mean_value = np.nanmean(filtered_data)
    std_dev = np.nanstd(filtered_data)
    percentiles = np.nanpercentile(filtered_data, [50, 80, 90])
    return mean_value, std_dev, percentiles

for band_name, band_filter in latitude_bands.items():
    band_lat_indices = np.where(band_filter)[0]
    filtered_data = sst_data[band_lat_indices, :]
    filtered_data = filtered_data[~np.isnan(filtered_data)]

    for value_range in value_ranges:
        range_filter = (filtered_data >= value_range[0]) & (filtered_data <= value_range[1])
        filtered_values = filtered_data[range_filter]
        regional_pixels_local=filtered_data.shape[0]
        valid_pixels = filtered_values.shape[0]
        Fraction_Valid_local = valid_pixels / regional_pixels_local
        Fraction_Valid_global = valid_pixels / regional_pixels_global
        
        if valid_pixels > 0:
            mean_value, std_dev, percentiles = calculate_metrics(filtered_values)
            print(f"\nLatitude Band: {band_name}")
            print(f"Value Range: {value_range}")
            print(f"Valid Pixels: {valid_pixels}")
            print(f"Fraction Valid wrt local region: {Fraction_Valid_local}")
            print(f"Fraction Valid wrt global region: {Fraction_Valid_global}")
            print(f"Mean: {mean_value}")
            print(f"Standard Deviation: {std_dev}")
            print(f"50th Percentile: {percentiles[0]}")
            print(f"80th Percentile: {percentiles[1]}")
            print(f"90th Percentile: {percentiles[2]}")
            plot_histogram(filtered_values, value_range)
            plot_cdf(filtered_values, value_range)
        else:
            print(f"\nLatitude Band: {band_name}")
            print(f"Value Range: {value_range}")
            print("No data in this range.")
# Out:
# Total Global Pixels 21290181
#
# Latitude Band: (30-60)N-(30-60)S
# Value Range: (0, 1)
# Valid Pixels: 8388189
# Fraction Valid wrt local region: 0.9327467806338643
# Fraction Valid wrt global region: 0.3939933155100936
# Mean: 0.24928806722164154
# Standard Deviation: 0.17904305458068848
# 50th Percentile: 0.19326023757457733
# 80th Percentile: 0.3524430990219116
# 90th Percentile: 0.4937412202358246
# Latitude Band: (30-60)N-(30-60)S
# Value Range: (0, 2)
# Valid Pixels: 8711418
# Fraction Valid wrt local region: 0.9686890810705263
# Fraction Valid wrt global region: 0.40917538465267156
# Mean: 0.29071861505508423
# Standard Deviation: 0.27969449758529663
# 50th Percentile: 0.1989414095878601
# 80th Percentile: 0.3854548275470734
# 90th Percentile: 0.5832775771617889
# Latitude Band: (30-60)N-(30-60)S
# Value Range: (1, 2)
# Valid Pixels: 323229
# Fraction Valid wrt local region: 0.035942300436661995
# Fraction Valid wrt global region: 0.01518206914257798
# Mean: 1.3658889532089233
# Standard Deviation: 0.275549054145813
# 50th Percentile: 1.3027458190917969
# 80th Percentile: 1.6373360157012942
# 90th Percentile: 1.8001879453659058
# Latitude Band: (60-90)N-(60-90)S
# Value Range: (0, 1)
# Valid Pixels: 2442440
# Fraction Valid wrt local region: 0.8031156061115229
# Fraction Valid wrt global region: 0.11472142956417326
# Mean: 0.3644688129425049
# Standard Deviation: 0.24677890539169312
# 50th Percentile: 0.2924490422010422
# 80th Percentile: 0.6024675726890565
# 90th Percentile: 0.7354479908943177
# Latitude Band: (60-90)N-(60-90)S
# Value Range: (0, 2)
# Valid Pixels: 2705327
# Fraction Valid wrt local region: 0.8895573006235027
# Fraction Valid wrt global region: 0.12706923440434817
# Mean: 0.46241992712020874
# Standard Deviation: 0.389407217502594
# 50th Percentile: 0.3494185507297516
# 80th Percentile: 0.7127805948257446
# 90th Percentile: 0.9873439908027647
# Latitude Band: (60-90)N-(60-90)S
# Value Range: (1, 2)
# Valid Pixels: 262887
# Fraction Valid wrt local region: 0.08644169451197979
# Fraction Valid wrt global region: 0.012347804840174914
# Mean: 1.372468113899231
# Standard Deviation: 0.27810561656951904
# 50th Percentile: 1.313570499420166
# 80th Percentile: 1.6482914686203003
# 90th Percentile: 1.8056597709655762
